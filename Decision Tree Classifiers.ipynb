# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# import dataset:
df = sns.load_dataset('iris')
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
from sklearn.tree import DecisionTreeClassifier
x = df.iloc[ : , :-1]
y = df.iloc[ : , -1]

# %%
x.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
y.head()
# Out:
# 0    setosa
# 1    setosa
# 2    setosa
# 3    setosa
# 4    setosa
# Name: species, dtype: object

# %%
# Creating the model:
from sklearn.tree import plot_tree

model = DecisionTreeClassifier().fit(x,y)
plot_tree(model, filled=True)
plt.title("Decision tree trained of IRIS data")

# Saving this model in tif,png and pdf file with HD quality:
#plt.savfig('DecisionTree.png', dpi=300)

plt.savefig('tiff_compressed_tif', dpi=800, format='tiff',
           facecolor = 'white',
           edgecolor = 'none',
           pil_kwargs={'compression': 'tiff_lzw'})
plt.show()

# %%
# Finding accuracy score:
# Import necessary libraries
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree

# Splitting data:
x_train,x_test,y_train,y_test = train_test_split(x,y, test_size=0.2, random_state=42)

# %%
# Create and train the model:
model = DecisionTreeClassifier().fit(x_train,y_train)

# %%
# Predict on the test values:
predicted_value = model.predict(x_test)

# calculate the accuracy score:
score = accuracy_score(y_test, predicted_value)
print(f'Accuracy score: {score}')
# Out:
# Accuracy score: 1.0

# %%
# plot the decision tree:
plt.figure(figsize=(20,10))
plot_tree(model, filled=True, feature_names=x.columns, class_names=sorted(y.unique()))
plt.title(f"Decision tree trained on the dataset:")
# Out:
# Text(0.5, 1.0, 'Decision tree trained on the dataset:')

# %%
# Save the plot in high-quality formats
plt.savefig('DecisionTree.png', dpi=300)
plt.savefig('DecisionTree.tiff', dpi=600, format='tiff', facecolor='white', edgecolor='none', pil_kwargs={'compression': 'tiff_lzw'})
plt.savefig('DecisionTree.pdf', dpi=300, format='pdf')

# Show the plot
plt.show()

# %%
# Sample value prediction
# Assuming your sample data has the same structure as the training data
sample_data = pd.DataFrame([[58, 162, 66, 1]], columns=x.columns)  # Modify with actual sample values
sample_prediction = model.predict(sample_data)
print(f'Sample Prediction: {sample_prediction}')
# Out:
# Sample Prediction: ['virginica']
